# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/yolo11-epoch100/README.dataset.txt
# /kaggle/input/yolo11-epoch100/README.roboflow.txt
# /kaggle/input/yolo11-epoch100/data.yaml
# /kaggle/input/yolo11-epoch100/valid/labels/20211011_134729-Custom-_jpg.rf.18eb2f63fe7aded7b79d6949dd7bee2c.txt
# /kaggle/input/yolo11-epoch100/valid/labels/IMG_20211107_125918-Custom-_jpg.rf.78a71e7972b0e4d4216f36535cada5ff.txt
# /kaggle/input/yolo11-epoch100/valid/labels/20211109_121455-Custom-_jpg.rf.c73aafb0160579891b079ae4fa09039f.txt
# /kaggle/input/yolo11-epoch100/valid/labels/IMG_20211108_122754-Custom-_jpg.rf.8227fb31258ec0033a139fb8a21a8d88.txt
# /kaggle/input/yolo11-epoch100/valid/labels/Gall-Midge00063_JPG.rf.c6767edd1574a55e9b54fa2a5669784e.txt
# /kaggle/input/yolo11-epoch100/valid/labels/IMG_20211106_121331-Custom-_jpg.rf.aa420679a9c69f330594621ee0030ae5.txt
# /kaggle/input/yolo11-epoch100/valid/labels/IMG_20211011_161705-Custom-_jpg.rf.9acf01cec795c0ea89da41a7acd47ac6.txt
# ...

# %%
# !pip install ultralytics -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.2/949.2 kB 15.5 MB/s eta 0:00:00a 0:00:01

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolo11n.pt")
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 17.9MB/s]

# %%
# Train the model
results = model.train(data="/kaggle/input/yolo11-epoch100/data.yaml", epochs=50, imgsz=640)
# Out:
# Ultralytics 8.3.91 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO("/kaggle/working/runs/detect/train/weights/best.pt")  # load a custom model

# %%
# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps  # a list contains map50-95 of each category
# Out:
# Ultralytics 8.3.91 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,583,322 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /kaggle/input/yolo11-epoch100/valid/labels... 360 images, 0 backgrounds, 0 corrupt: 100%|██████████| 360/360 [00:00<00:00, 501.32it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/yolo11-epoch100/valid is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 23/23 [00:03<00:00,  5.89it/s]
#                    all        360        360      0.995      0.993      0.994        0.9
#            Anthracnose         65         65      0.998          1      0.995       0.92
#       Bacterial Canker         54         54      0.998          1      0.995      0.868
#             Gall Midge         82         82      0.985      0.988      0.994      0.876
# ...

# %%
# Predict with the model

results = model("/kaggle/input/yolo11-epoch100/test/images", save=True, save_txt=True)


# Access the results
for result in results:
    xywh = result.boxes.xywh  # center-x, center-y, width, height
    xywhn = result.boxes.xywhn  # normalized
    xyxy = result.boxes.xyxy  # top-left-x, top-left-y, bottom-right-x, bottom-right-y
    xyxyn = result.boxes.xyxyn  # normalized
    names = [result.names[cls.item()] for cls in result.boxes.cls.int()]  # class name of each box
    confs = result.boxes.conf  # confidence score of each box
# Out:
# image 1/180 /kaggle/input/yolo11-epoch100/test/images/20211011_131259-Custom-_jpg.rf.4aaa8000d482712362b660dc9d4c1d26.jpg: 640x640 1 Anthracnose, 9.5ms
# image 2/180 /kaggle/input/yolo11-epoch100/test/images/20211011_131304-Custom-_jpg.rf.f264197ce4d64f697f87cd12f5c264dd.jpg: 640x640 1 Anthracnose, 9.2ms
# image 3/180 /kaggle/input/yolo11-epoch100/test/images/20211011_133203-Custom-_jpg.rf.a0cd126c1c23b1d62817371e6aae427a.jpg: 640x640 1 Anthracnose, 9.1ms
# image 4/180 /kaggle/input/yolo11-epoch100/test/images/20211011_133419-Custom-_jpg.rf.d91a0617fb7a28d17a0da00b4536d716.jpg: 640x640 1 Anthracnose, 9.0ms
# image 5/180 /kaggle/input/yolo11-epoch100/test/images/20211011_133426-Custom-_jpg.rf.2527ae0c79738b2929c71cbefa701e04.jpg: 640x640 1 Anthracnose, 9.1ms
# image 6/180 /kaggle/input/yolo11-epoch100/test/images/20211011_133745-Custom-_jpg.rf.ec79ffb491656b452461e6669620b942.jpg: 640x640 1 Anthracnose, 8.5ms
# ...

# %%
# Predict with the model

results = model("/kaggle/input/yolov8-model-implementation/test/images", save=True, save_txt=True)


# Access the results
for result in results:
    xywh = result.boxes.xywh  # center-x, center-y, width, height
    xywhn = result.boxes.xywhn  # normalized
    xyxy = result.boxes.xyxy  # top-left-x, top-left-y, bottom-right-x, bottom-right-y
    xyxyn = result.boxes.xyxyn  # normalized
    names = [result.names[cls.item()] for cls in result.boxes.cls.int()]  # class name of each box
    confs = result.boxes.conf  # confidence score of each box

# %%
# Predict with the model

results = model("/kaggle/input/predict/anthracnose pic 3.jpg", save=True, save_txt=True)


# Access the results
for result in results:
    xywh = result.boxes.xywh  # center-x, center-y, width, height
    xywhn = result.boxes.xywhn  # normalized
    xyxy = result.boxes.xyxy  # top-left-x, top-left-y, bottom-right-x, bottom-right-y
    xyxyn = result.boxes.xyxyn  # normalized
    names = [result.names[cls.item()] for cls in result.boxes.cls.int()]  # class name of each box
    confs = result.boxes.conf  # confidence score of each box
# Out:
# image 1/1 /kaggle/input/predict/anthracnose pic 3.jpg: 640x544 1 Anthracnose, 47.9ms
# Speed: 3.2ms preprocess, 47.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 544)
# Results saved to runs/detect/predict
# 181 labels saved to runs/detect/predict/labels

# %%
# Predict with the model

results = model("/kaggle/input/predict/anthracnose pic2.png", save=True, save_txt=True)


# Access the results
for result in results:
    xywh = result.boxes.xywh  # center-x, center-y, width, height
    xywhn = result.boxes.xywhn  # normalized
    xyxy = result.boxes.xyxy  # top-left-x, top-left-y, bottom-right-x, bottom-right-y
    xyxyn = result.boxes.xyxyn  # normalized
    names = [result.names[cls.item()] for cls in result.boxes.cls.int()]  # class name of each box
    confs = result.boxes.conf  # confidence score of each box
# Out:
# image 1/1 /kaggle/input/predict/anthracnose pic2.png: 448x640 1 Anthracnose, 47.5ms
# Speed: 2.2ms preprocess, 47.5ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# 182 labels saved to runs/detect/predict/labels

# %%
# Predict with the model

results = model("/kaggle/input/predict/gall midge pic.png", save=True, save_txt=True)


# Access the results
for result in results:
    xywh = result.boxes.xywh  # center-x, center-y, width, height
    xywhn = result.boxes.xywhn  # normalized
    xyxy = result.boxes.xyxy  # top-left-x, top-left-y, bottom-right-x, bottom-right-y
    xyxyn = result.boxes.xyxyn  # normalized
    names = [result.names[cls.item()] for cls in result.boxes.cls.int()]  # class name of each box
    confs = result.boxes.conf  # confidence score of each box
# Out:
# image 1/1 /kaggle/input/predict/gall midge pic.png: 480x640 1 Gall Midge, 47.6ms
# Speed: 2.3ms preprocess, 47.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict
# 184 labels saved to runs/detect/predict/labels

# %%
# Predict with the model

results = model("/kaggle/input/predict/gall midge pic 2.png", save=True, save_txt=True)


# Access the results
for result in results:
    xywh = result.boxes.xywh  # center-x, center-y, width, height
    xywhn = result.boxes.xywhn  # normalized
    xyxy = result.boxes.xyxy  # top-left-x, top-left-y, bottom-right-x, bottom-right-y
    xyxyn = result.boxes.xyxyn  # normalized
    names = [result.names[cls.item()] for cls in result.boxes.cls.int()]  # class name of each box
    confs = result.boxes.conf  # confidence score of each box
# Out:
# image 1/1 /kaggle/input/predict/gall midge pic 2.png: 480x640 1 Gall Midge, 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict
# 186 labels saved to runs/detect/predict/labels

# %%
# Predict with the model

results = model("/kaggle/input/predict/powder mildew pic 1.jpg", save=True, save_txt=True)


# Access the results
for result in results:
    xywh = result.boxes.xywh  # center-x, center-y, width, height
    xywhn = result.boxes.xywhn  # normalized
    xyxy = result.boxes.xyxy  # top-left-x, top-left-y, bottom-right-x, bottom-right-y
    xyxyn = result.boxes.xyxyn  # normalized
    names = [result.names[cls.item()] for cls in result.boxes.cls.int()]  # class name of each box
    confs = result.boxes.conf  # confidence score of each box
# Out:
# image 1/1 /kaggle/input/predict/powder mildew pic 1.jpg: 480x640 1 Anthracnose, 1 Powdery Mildew, 11.8ms
# Speed: 2.1ms preprocess, 11.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict
# 188 labels saved to runs/detect/predict/labels

# %%
# Predict with the model

results = model("/kaggle/input/predict/powdery mildew 4.png", save=True, save_txt=True)


# Access the results
for result in results:
    xywh = result.boxes.xywh  # center-x, center-y, width, height
    xywhn = result.boxes.xywhn  # normalized
    xyxy = result.boxes.xyxy  # top-left-x, top-left-y, bottom-right-x, bottom-right-y
    xyxyn = result.boxes.xyxyn  # normalized
    names = [result.names[cls.item()] for cls in result.boxes.cls.int()]  # class name of each box
    confs = result.boxes.conf  # confidence score of each box
# Out:
# image 1/1 /kaggle/input/predict/powdery mildew 4.png: 448x640 2 Powdery Mildews, 10.1ms
# Speed: 2.1ms preprocess, 10.1ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# 189 labels saved to runs/detect/predict/labels

# %%
# Predict with the model

results = model("/kaggle/input/predict/sooty mould pic 3.png", save=True, save_txt=True)


# Access the results
for result in results:
    xywh = result.boxes.xywh  # center-x, center-y, width, height
    xywhn = result.boxes.xywhn  # normalized
    xyxy = result.boxes.xyxy  # top-left-x, top-left-y, bottom-right-x, bottom-right-y
    xyxyn = result.boxes.xyxyn  # normalized
    names = [result.names[cls.item()] for cls in result.boxes.cls.int()]  # class name of each box
    confs = result.boxes.conf  # confidence score of each box
# Out:
# image 1/1 /kaggle/input/predict/sooty mould pic 3.png: 640x448 1 Sooty Mould, 10.3ms
# Speed: 2.0ms preprocess, 10.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to runs/detect/predict
# 191 labels saved to runs/detect/predict/labels

# %%
import shutil
from IPython.display import FileLink

# Specify the folder you want to zip (typically 'runs/detect/train' or similar if you're training YOLO)
output_folder = '/kaggle/working/runs'  # Replace with the folder you want to zip
zip_filename = 'ObjectDetection2_output.zip'   # The name of the zip file

# Zip the folder
shutil.make_archive(zip_filename.replace('.zip', ''), 'zip', output_folder)

# Generate a download link for the zip file
FileLink(zip_filename)
# Out:
# /kaggle/working/ObjectDetection2_output.zip
